# %%
import pandas as pd
import numpy as np
from tensorflow import keras as keras

#Libraries to create the multiclass model
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
#Import tensorflow and disable the v2 behavior and eager mode
import tensorflow as tf

#Libraries to pre-process the variables
from sklearn.preprocessing import LabelEncoder,MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
df1 = pd.read_csv('data_moods.csv')

# %%
df2 = pd.read_csv('dataset1.csv')

# %%
df1
# Out:
#                                             name  \
# 0                                           1999
# 1                                             23
# 2                                       9 Crimes
# 3                                 99 Luftballons
# 4    A Boy Brushed Red Living In Black And White
# ..                                           ...
# 681                                  windcatcher
# 682              yellow is the color of her eyes
# 683                           you broke me first
# 684                          you were good to me
# 685                                         æfre
#
#                                album          artist                      id  \
# 0                               1999          Prince  2H7PHVdQ3mXqEHXcvclTB0
# 1                                 23  Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP
# 2                                  9     Damien Rice  5GZEeowhvSieFDiR8fQ2im
# 3                     99 Luftballons            Nena  6HA97v4wEGQ5TUClRM0XLc
# 4        They're Only Chasing Safety       Underoath  47IWLfIKOKhFnz1FUEUIkE
# ..                               ...             ...                     ...
# 681                      windcatcher       Leo Nocta  59VApBbrS2IADQk4ml5mdo
# 682  yellow is the color of her eyes    Soccer Mommy  4D3nttJPU6L0M2epr7sId6
# 683               you broke me first      Tate McRae  45bE4HXI0AwGZXfZtMp8JR
# 684                            brent   Jeremy Zucker  4CxFN5zON70B3VOPBYbd6P
# 685                             æfre           praam  2irbT1BSYaIEF44PlyKaoM
#
#     release_date  popularity  length  danceability  acousticness  energy  \
# 0     1982-10-27          68  379266         0.866       0.13700  0.7300
# 1     2007-04-16          43  318800         0.381       0.01890  0.8320
# 2     2006-11-06          60  217946         0.346       0.91300  0.1390
# 3     1984-08-21           2  233000         0.466       0.08900  0.4380
# 4     2004-01-01          60  268000         0.419       0.00171  0.9320
# ..           ...         ...     ...           ...           ...     ...
# 681   2020-06-19          36  123066         0.402       0.96100  0.2360
# 682   2019-11-19           5  435080         0.452       0.75700  0.5150
# 683   2020-04-17          87  169265         0.642       0.78600  0.3740
# 684   2019-05-03          76  219146         0.561       0.91300  0.0848
# 685   2020-07-17          41  186331         0.377       0.99400  0.0156
#
#      instrumentalness  liveness  valence  loudness  speechiness    tempo  key  \
# 0            0.000000    0.0843   0.6250    -8.201       0.0767  118.523    5
# 1            0.196000    0.1530   0.1660    -5.069       0.0492  120.255    8
# 2            0.000077    0.0934   0.1160   -15.326       0.0321  136.168    0
# 3            0.000006    0.1130   0.5870   -12.858       0.0608  193.100    4
# 4            0.000000    0.1370   0.4450    -3.604       0.1060  169.881    1
# ..                ...       ...      ...       ...          ...      ...  ...
# 681          0.919000    0.0921   0.1460   -20.615       0.0603  129.736    0
# 682          0.120000    0.1400   0.1910    -7.351       0.0255   80.537   11
# 683          0.000000    0.0906   0.0799    -9.386       0.0545  124.099    4
# 684          0.000026    0.1120   0.2060   -15.099       0.0404  102.128    2
# 685          0.881000    0.0991   0.0804   -28.435       0.0397  140.179    0
#
#      time_signature       mood
# 0                 4      Happy
# 1                 4        Sad
# 2                 4        Sad
# 3                 4      Happy
# 4                 4  Energetic
# ..              ...        ...
# 681               3       Calm
# 682               4        Sad
# 683               4        Sad
# 684               4        Sad
# 685               4       Calm
#
# [686 rows x 19 columns]

# %%
df2 = df2.drop(['Unnamed: 0'],axis=1)

# %%
df2
# Out:
#      danceability   energy  loudness  speechiness  acousticness  \
# 0           0.287  0.12000   -23.170       0.0334       0.75600
# 1           0.248  0.14600   -21.551       0.0373       0.89300
# 2           0.413  0.14800   -19.361       0.0339       0.60300
# 3           0.515  0.06040   -23.755       0.0324       0.97300
# 4           0.507  0.00721   -26.424       0.0361       0.97800
# ..            ...      ...       ...          ...           ...
# 525         0.613  0.92300    -5.234       0.0691       0.00892
# 526         0.516  0.68400    -5.659       0.0797       0.65200
# 527         0.636  0.88100    -5.376       0.0758       0.13400
# 528         0.526  0.76300   -12.663       0.0341       0.00126
# 529         0.618  0.83700    -5.574       0.1150       0.08420
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.888000    0.0916   0.0402   70.212  2MuaFOZj37wxfuE5owVhF9
# 1            0.725000    0.0957   0.0353   73.963  1GwaCX84BPG0GRoC0zIa9P
# 2            0.848000    0.0961   0.0574  143.578  04JXK1GuqYWZHaRPpdIiv9
# 3            0.494000    0.1410   0.1750   79.958  1UuovFMJZO3lThwwVBafbN
# 4            0.894000    0.1070   0.0390   85.065  5FiIDwTS9PJKMy2fcKp0k1
# ..                ...       ...      ...      ...                     ...
# 525          0.000000    0.1490   0.6690   96.043  2kiJ5lZQZusgWwpqA7z2i1
# 526          0.000000    0.6850   0.8400  161.167  0BbA7S30mOQB94e4IBnqCt
# 527          0.009520    0.0740   0.8450  118.237  7BXToqZFtclAj6mshYWena
# 528          0.000068    0.3590   0.5140  136.205  20CNpCKq1oTdvekXaboyeq
# 529          0.000000    0.3440   0.8000  168.114  1bxa0TPdBMHPeZFHe0adCw
#
#                                       uri  duration_ms      mood
# 0    spotify:track:2MuaFOZj37wxfuE5owVhF9        85714  Relaxing
# 1    spotify:track:1GwaCX84BPG0GRoC0zIa9P        94648  Relaxing
# 2    spotify:track:04JXK1GuqYWZHaRPpdIiv9        87500  Relaxing
# 3    spotify:track:1UuovFMJZO3lThwwVBafbN        72000  Relaxing
# 4    spotify:track:5FiIDwTS9PJKMy2fcKp0k1        97037  Relaxing
# ..                                    ...          ...       ...
# 525  spotify:track:2kiJ5lZQZusgWwpqA7z2i1       166920     Happy
# 526  spotify:track:0BbA7S30mOQB94e4IBnqCt       131160     Happy
# 527  spotify:track:7BXToqZFtclAj6mshYWena       133467     Happy
# 528  spotify:track:20CNpCKq1oTdvekXaboyeq       215160     Happy
# 529  spotify:track:1bxa0TPdBMHPeZFHe0adCw       174800     Happy
#
# [530 rows x 13 columns]

# %%
res = pd.concat([df1,df2])

# %%
res
# Out:
#                                             name                        album  \
# 0                                           1999                         1999
# 1                                             23                           23
# 2                                       9 Crimes                            9
# 3                                 99 Luftballons               99 Luftballons
# 4    A Boy Brushed Red Living In Black And White  They're Only Chasing Safety
# ..                                           ...                          ...
# 525                                          NaN                          NaN
# 526                                          NaN                          NaN
# 527                                          NaN                          NaN
# 528                                          NaN                          NaN
# 529                                          NaN                          NaN
#
#              artist                      id release_date  popularity  \
# 0            Prince  2H7PHVdQ3mXqEHXcvclTB0   1982-10-27        68.0
# 1    Blonde Redhead  4HIwL9ii9CcXpTOTzMq0MP   2007-04-16        43.0
# 2       Damien Rice  5GZEeowhvSieFDiR8fQ2im   2006-11-06        60.0
# 3              Nena  6HA97v4wEGQ5TUClRM0XLc   1984-08-21         2.0
# 4         Underoath  47IWLfIKOKhFnz1FUEUIkE   2004-01-01        60.0
# ..              ...                     ...          ...         ...
# 525             NaN  2kiJ5lZQZusgWwpqA7z2i1          NaN         NaN
# 526             NaN  0BbA7S30mOQB94e4IBnqCt          NaN         NaN
# 527             NaN  7BXToqZFtclAj6mshYWena          NaN         NaN
# 528             NaN  20CNpCKq1oTdvekXaboyeq          NaN         NaN
# 529             NaN  1bxa0TPdBMHPeZFHe0adCw          NaN         NaN
#
#        length  danceability  acousticness  energy  ...  liveness  valence  \
# 0    379266.0         0.866       0.13700   0.730  ...    0.0843    0.625
# 1    318800.0         0.381       0.01890   0.832  ...    0.1530    0.166
# 2    217946.0         0.346       0.91300   0.139  ...    0.0934    0.116
# 3    233000.0         0.466       0.08900   0.438  ...    0.1130    0.587
# 4    268000.0         0.419       0.00171   0.932  ...    0.1370    0.445
# ..        ...           ...           ...     ...  ...       ...      ...
# 525       NaN         0.613       0.00892   0.923  ...    0.1490    0.669
# 526       NaN         0.516       0.65200   0.684  ...    0.6850    0.840
# 527       NaN         0.636       0.13400   0.881  ...    0.0740    0.845
# 528       NaN         0.526       0.00126   0.763  ...    0.3590    0.514
# 529       NaN         0.618       0.08420   0.837  ...    0.3440    0.800
#
#      loudness  speechiness    tempo  key  time_signature       mood  \
# 0      -8.201       0.0767  118.523  5.0             4.0      Happy
# 1      -5.069       0.0492  120.255  8.0             4.0        Sad
# 2     -15.326       0.0321  136.168  0.0             4.0        Sad
# 3     -12.858       0.0608  193.100  4.0             4.0      Happy
# 4      -3.604       0.1060  169.881  1.0             4.0  Energetic
# ..        ...          ...      ...  ...             ...        ...
# 525    -5.234       0.0691   96.043  NaN             NaN      Happy
# 526    -5.659       0.0797  161.167  NaN             NaN      Happy
# 527    -5.376       0.0758  118.237  NaN             NaN      Happy
# 528   -12.663       0.0341  136.205  NaN             NaN      Happy
# 529    -5.574       0.1150  168.114  NaN             NaN      Happy
#
#                                       uri duration_ms
# 0                                     NaN         NaN
# 1                                     NaN         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
# ..                                    ...         ...
# 525  spotify:track:2kiJ5lZQZusgWwpqA7z2i1    166920.0
# 526  spotify:track:0BbA7S30mOQB94e4IBnqCt    131160.0
# 527  spotify:track:7BXToqZFtclAj6mshYWena    133467.0
# 528  spotify:track:20CNpCKq1oTdvekXaboyeq    215160.0
# 529  spotify:track:1bxa0TPdBMHPeZFHe0adCw    174800.0
#
# [1216 rows x 21 columns]

# %%
#
#Define the features and the target
col_features = ['energy', 'liveness', 'tempo', 'speechiness',
                                     'acousticness', 'instrumentalness', 'danceability',
                                     'loudness', 'valence']
X = res[col_features]
Y = res['mood']
#Normalize the features
X= MinMaxScaler().fit_transform(X)
#Encode the labels (targets)
encoder = LabelEncoder()
encoder.fit(Y)
encoded_y = encoder.transform(Y)
#Split train and test data with a test size of 20%
X_train,X_test,Y_train,Y_test = train_test_split(X,encoded_y,test_size=0.2,random_state=15)

# %%
#Libraries to create the Multi-class Neural Network
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils

# %%
#Import tensorflow and disable the v2 behavior and eager mode
import tensorflow as tf
tf.compat.v1.disable_eager_execution()
tf.compat.v1.disable_v2_behavior()

# %%
#Function that creates the structure of the Neural Network
def base_model():
    #Create the model
    model = Sequential()
#Add 1 layer with 8 nodes,input of 4 dim with relu function
    model.add(Dense(8,input_dim=10,activation='relu'))
#Add 1 layer with output 3 and softmax function
    model.add(Dense(4,activation='softmax'))
#Compile the model using logistic loss function and adam     optimizer, accuracy correspond to the metric displayed
    model.compile(loss='categorical_crossentropy',optimizer='adam',
              metrics=['accuracy'])
    
    return model
    
#Configure the estimator with 300 epochs and 200 batchs. the build_fn takes the function defined above.
estimator = KerasClassifier(build_fn=base_model,epochs=300,
                            batch_size=200)
# Out:
# /var/folders/zz/x23587pj6wg74rj89_9jchfc0000gn/T/ipykernel_42309/864019933.py:16: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   estimator = KerasClassifier(build_fn=base_model,epochs=300,

# %%
#Library to evaluate the model
from sklearn.model_selection import cross_val_score, KFold

# %%
#Evaluate the model using KFold cross validation
kfold = KFold(n_splits=10,shuffle=True)
results = cross_val_score(estimator,X,encoded_y,cv=kfold)
print("%.2f%% (%.2f%%)" % (results.mean()*100,results.std()*100))
# Out:
# nan% (nan%)
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 10 fits failed out of a total of 10.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_118_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_120_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_122_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_124_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_126_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_128_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_130_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_132_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_134_input to have shape (10,) but got array with shape (9,)
#
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 236, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/wrappers/scikit_learn.py", line 164, in fit
#     history = self.model.fit(x, y, **fit_args)
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 776, in fit
#     return func.fit(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_arrays_v1.py", line 616, in fit
#     x, y, sample_weights = model._standardize_user_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2323, in _standardize_user_data
#     return self._standardize_tensors(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_v1.py", line 2351, in _standardize_tensors
#     x = training_utils_v1.standardize_input_data(
#   File "/opt/anaconda3/lib/python3.9/site-packages/keras/engine/training_utils_v1.py", line 642, in standardize_input_data
#     raise ValueError('Error when checking ' + exception_prefix +
# ValueError: Error when checking input: expected dense_136_input to have shape (10,) but got array with shape (9,)
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
